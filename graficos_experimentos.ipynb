# %%
# Graficas para los experimentos

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Experimento 1
ITERATIONS = 10

learning_rates = np.array([0.5, 1.5, 2.5, 3.5])            # Resultados
iterations = np.linspace(1, ITERATIONS, num=ITERATIONS)

combinaciones = np.array(np.meshgrid(iterations, learning_rates)).T.reshape(-1,2)
df_hiperparametros = pd.DataFrame(combinaciones, columns=['Iterations', 'Learning Rate'])


for i in range(len(df_hiperparametros)):
    print(f"Iterations: {df_hiperparametros["Iterations"][i]},  Learning Rate: {df_hiperparametros["Learning Rate"][i]}")
    df_hiperparametros["Cost"] = df_hiperparametros.index    # sustituir con el resultado de la función de coste después del entrenamiento
# Out:
# Iterations: 1.0,  Learning Rate: 0.5
# Iterations: 1.0,  Learning Rate: 1.5
# Iterations: 1.0,  Learning Rate: 2.5
# Iterations: 1.0,  Learning Rate: 3.5
# Iterations: 2.0,  Learning Rate: 0.5
# Iterations: 2.0,  Learning Rate: 1.5
# Iterations: 2.0,  Learning Rate: 2.5
# Iterations: 2.0,  Learning Rate: 3.5
# Iterations: 3.0,  Learning Rate: 0.5
# Iterations: 3.0,  Learning Rate: 1.5
# Iterations: 3.0,  Learning Rate: 2.5
# Iterations: 3.0,  Learning Rate: 3.5
# Iterations: 4.0,  Learning Rate: 0.5
# Iterations: 4.0,  Learning Rate: 1.5
# Iterations: 4.0,  Learning Rate: 2.5
# Iterations: 4.0,  Learning Rate: 3.5
# Iterations: 5.0,  Learning Rate: 0.5
# Iterations: 5.0,  Learning Rate: 1.5
# Iterations: 5.0,  Learning Rate: 2.5
# Iterations: 5.0,  Learning Rate: 3.5
# Iterations: 6.0,  Learning Rate: 0.5
# Iterations: 6.0,  Learning Rate: 1.5
# Iterations: 6.0,  Learning Rate: 2.5
# Iterations: 6.0,  Learning Rate: 3.5
# Iterations: 7.0,  Learning Rate: 0.5
# Iterations: 7.0,  Learning Rate: 1.5
# Iterations: 7.0,  Learning Rate: 2.5
# Iterations: 7.0,  Learning Rate: 3.5
# Iterations: 8.0,  Learning Rate: 0.5
# Iterations: 8.0,  Learning Rate: 1.5
# Iterations: 8.0,  Learning Rate: 2.5
# Iterations: 8.0,  Learning Rate: 3.5
# Iterations: 9.0,  Learning Rate: 0.5
# Iterations: 9.0,  Learning Rate: 1.5
# Iterations: 9.0,  Learning Rate: 2.5
# Iterations: 9.0,  Learning Rate: 3.5
# Iterations: 10.0,  Learning Rate: 0.5
# Iterations: 10.0,  Learning Rate: 1.5
# Iterations: 10.0,  Learning Rate: 2.5
# Iterations: 10.0,  Learning Rate: 3.5

# %%
for learning_rate, group in df_hiperparametros.groupby('Learning Rate'):
    plt.plot(group['Iterations'], group['Cost'], '-o', label=f"Learning rate = {learning_rate}")

plt.xlabel('Iteraciones')
plt.ylabel('Cost function')
plt.title('Convergencia de la función de coste')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Experimento 2
N_WORKERS = 4

execution_time = np.array([250, 150, 100, 50])            # Resultados
n_workers = np.linspace(1, N_WORKERS, num=N_WORKERS)


plt.plot(n_workers, execution_time, '-o')
plt.xticks(n_workers)
plt.title('Experimento 2 - Execution Time vs Workers')
plt.xlabel('Workers')
plt.ylabel('Execution time (s)')
plt.grid(True)
plt.show()


speed_up = execution_time[0] / execution_time
plt.plot(n_workers, speed_up, '-o')
plt.xticks(n_workers)
plt.title('Experimento 2 - Speed-up vs Workers')
plt.xlabel('Workers')
plt.ylabel('Speed-up (T1 / Tn)')
plt.grid(True)
plt.show()

# %%
# Experimento 3

resultados = {
  "No cache" : 2,
  "Cache after map" : 1,
  "Cache after join" : 1,
  "Cache after reduce by key" : 1,
  "Cache at source" : 3
}

plt.bar(resultados.keys(), resultados.values())
plt.xticks(rotation=45)
plt.title('Experimento 3 - Catching strategy vs. Execution time')
plt.ylabel('Execution time (s)')
plt.show()


# 3.b => (Reptit experimetn 2 with the best caching strategy)

# %%
# Experimento 4
N_PARTITIONS = 4

execution_time = np.array([250, 150, 100, 50])
n_partitions = np.linspace(1, N_PARTITIONS, num=N_PARTITIONS)


plt.plot(n_partitions, execution_time, '-o')
plt.xticks(n_partitions)
plt.legend(['Workers = 4'])
plt.title('Experimento 4 - Partitions')
plt.xlabel('Partitions')
plt.ylabel('Execution time (s)')
plt.grid(True)
plt.show()

# %%
# Experimento 5
N_WORKERS = 4

n_workers = np.linspace(1, N_WORKERS, num=N_WORKERS)
execution_time = np.array([250, 150, 100, 50])


plt.plot(n_workers, execution_time, '-o')
plt.xticks(n_workers)
plt.legend(['Partitions = 2'])
plt.title('Experimento 5 - Workers')
plt.xlabel('Workers')
plt.ylabel('Execution time (s)')
plt.grid(True)
plt.show()
